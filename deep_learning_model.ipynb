# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df = application_df.drop(columns=['EIN','NAME'])
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
num_unique_values = df.nunique()
print(num_unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   INCOME_AMT              34299 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  8   ASK_AMT                 34299 non-null  int64
#  9   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.6+ MB

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
app_type_counts = df['APPLICATION_TYPE'].value_counts()
app_type_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 250
application_types_to_replace =app_type_counts[app_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_count = df['CLASSIFICATION'].value_counts()
classification_count
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = df['CLASSIFICATION'].value_counts()[df['CLASSIFICATION'].value_counts() > 1]
classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_values = 1800
classifications_to_replace = classification_count[classification_count < cutoff_values].index.tolist()


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df_numeric = pd.get_dummies(df)

# Convert booleans to integers

df_numeric = df_numeric.astype(int)

df_numeric
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = df_numeric["IS_SUCCESSFUL"]
X = df_numeric.drop(columns="IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (25724, 116)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features = len(X_train.columns)

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                9360
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 11821 (46.18 KB)
# Trainable params: 11821 (46.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="Adamax", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5926 - accuracy: 0.7077
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5564 - accuracy: 0.7298
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5509 - accuracy: 0.7318
# Epoch 4/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5479 - accuracy: 0.7322
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7336
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7338
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7339
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7344
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7347
# Epoch 10/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5412 - accuracy: 0.7341
# Epoch 11/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5406 - accuracy: 0.7349
# Epoch 12/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7352
# Epoch 13/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7360
# Epoch 14/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7357
# Epoch 15/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7357
# Epoch 16/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7368
# Epoch 17/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7365
# Epoch 18/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5383 - accuracy: 0.7368
# Epoch 19/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7373
# Epoch 20/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7367
# Epoch 21/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7369
# Epoch 22/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7368
# Epoch 23/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7380
# Epoch 24/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5370 - accuracy: 0.7374
# Epoch 25/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5364 - accuracy: 0.7367
# Epoch 26/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7374
# Epoch 27/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7375
# Epoch 28/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7368
# Epoch 29/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7375
# Epoch 30/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7377
# Epoch 31/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7377
# Epoch 32/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5355 - accuracy: 0.7376
# Epoch 33/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7374
# Epoch 34/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7395
# Epoch 35/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7373
# Epoch 36/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7389
# Epoch 37/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7392
# Epoch 38/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7388
# Epoch 39/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5343 - accuracy: 0.7383
# Epoch 40/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7391
# Epoch 41/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7381
# Epoch 42/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7391
# Epoch 43/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7385
# Epoch 44/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7396
# Epoch 45/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7391
# Epoch 46/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5332 - accuracy: 0.7409
# Epoch 47/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7398
# Epoch 48/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7396
# Epoch 49/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7388
# Epoch 50/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7400

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5572 - accuracy: 0.7294 - 482ms/epoch - 2ms/step
# Loss: 0.5571757555007935, Accuracy: 0.7294460535049438

# %%
# Export our model to HDF5 file
from tensorflow.keras.models import save_model
save_model(nn, 'my_model.keras')

print("Model saved successfully as HDF5 file.")
# Out:
# Model saved successfully as HDF5 file.
